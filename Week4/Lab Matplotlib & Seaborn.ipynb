# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
# Your Code Here
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('fitbit2.csv')

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# AVERAGE STEPS BY MONTH_ENCODED
# your code here
fig, ax = plt.subplots(figsize=(12,4))
ax.set_title('Median steps by month')
ax.set_xlabel('Months')
ax.set_ylabel('Median steps')
ax.set_xticks(np.arange(1,13))
ax.set_xticklabels(['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
sns.boxplot(x='Months_encoded', y='Steps', data=fitbit, ax=ax)
plt.sca(ax)
plt.show()
fig.savefig('figures/median_steps_by_month.png')

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
# your code here
fig, ax = plt.subplots(figsize=(12,4))
ax.set_title('Average steps by work or weekend')
ax.set_xlabel('Work or weekend')
ax.set_ylabel('Average steps')
ax.set_xticks(np.arange(2))
ax.set_xticklabels(['Work','Weekend'])
sns.barplot(x='Work_or_Weekend', y='Steps', data=fitbit, ax=ax)
plt.sca(ax)
plt.show()
fig.savefig('figures/average_steps_by_work_or_weekend.png')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
plots = ['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary']
for i in range (3):
    fig, ax = plt.subplots(figsize=(12,4))
    #set the title
    ax.set_title(f'{plots[i]} vs Steps')
    #set the x axis
    ax.set_xlabel(plots[i])
    #set the y axis
    ax.set_ylabel('Steps')
    #plot the scatter plot
    sns.scatterplot(x=plots[i], y='Steps', data=fitbit, ax=ax)
    #show the plot
    plt.show()
    #save the plot
    fig.savefig(f'figures/_vs_steps{i}.png')

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('titanic.csv')

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
print(titanic.dtypes)
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
print(titanic.select_dtypes(include=['int64','float64']).columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# CATEGORICAL VARIABLES
# your code here
print(titanic.select_dtypes(include=['object']).columns)
# Out:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.style.use('classic')
plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
plt.hist(titanic['Age'])
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
fig, ax = plt.subplots(1,3, figsize=(12,6))
ax[0].set_title('Age distribution with 10 bins')
ax[1].set_title('Age distribution with 20 bins')
ax[2].set_title('Age distribution with 50 bins')
ax[0].set_xlabel('Age')
ax[1].set_xlabel('Age')
ax[2].set_xlabel('Age')
ax[0].set_ylabel('Frequency')
ax[1].set_ylabel('Frequency')
ax[2].set_ylabel('Frequency')
ax[0].hist(titanic['Age'], bins=10)
ax[1].hist(titanic['Age'], bins=20)
ax[2].hist(titanic['Age'], bins=50)
plt.show()
fig.savefig('figures/age_distribution.png')

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
More bins means more detail in the distribution
"""
# Out:
# '\nyour comments here\nMore bins means more detail in the distribution\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
fig, ax = plt.subplots(figsize=(12,6))
ax.set_title('Age distribution')
ax.set_xlabel('Age')
ax.set_ylabel('Frequency')
sns.distplot(titanic['Age'], ax=ax)
plt.show()
fig.savefig('figures/age_distribution_seaborn.png')
# Out:
# C:\Users\marti\AppData\Local\Temp\ipykernel_21500\113022326.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['Age'], ax=ax)

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
ig, ax = plt.subplots(figsize=(12,6))
ax.set_title('Gender distribution')
ax.set_xlabel('Gender')
ax.set_ylabel('Frequency')
ax.hist(x=titanic['Gender'])
plt.show()
fig.savefig('figures/Gender_distribution.png')

# %%
# Method 2 - seaborn
# your code here
fig, ax = plt.subplots(figsize=(12,6))
ax.set_title('Gender distribution (seaborn)')
ax.set_xlabel('Gender')
ax.set_ylabel('Frequency')
sns.countplot(x=titanic['Gender'])
plt.show()
fig.savefig('figures/Gender_distribution_seaborn.png')

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
fig, ax = plt.subplots(figsize=(12,6))
ax.set_title('Pclass distribution')
ax.set_xlabel('Pclass')
ax.set_ylabel('Frequency')
sns.countplot(x=titanic['Pclass'])
plt.show()
fig.savefig('figures/Pclass_distribution.png')

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
fig, ax = plt.subplots(figsize=(12,6))
ax.set_title('Age summary statistics')
ax.set_xlabel('Age')
ax.set_ylabel('Frequency')
sns.boxplot(x=titanic['Age'], ax=ax)
plt.show()
fig.savefig('figures/Age_summary_statistics.png')

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
The age average is around 30 years old and the median is around 28 years old. The age distribution is right skewed. The youngest passenger is 0.42 years old and the oldest is 80 years old.
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
fig, ax = plt.subplots(figsize=(12,6))
ax.set_title('Age summary statistics and distribution')
ax.set_xlabel('Age')
ax.set_ylabel('Frequency')
sns.violinplot(x=titanic['Age'], ax=ax)
plt.show()
fig.savefig('figures/Age_summary_statistics_and_distribution.png')

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
That the distribution tends to be more concentrated around the median and the interquartile range.

"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
fig, ax = plt.subplots(figsize=(12,6))
ax.set_title('Fare vs Age')
ax.set_xlabel('Age')
ax.set_ylabel('Fare')
ax.scatter(titanic['Age'], titanic['Fare'])
plt.show()
fig.savefig('figures/Fare_vs_Age.png')

# %%
# Method 2 - seaborn
# your code here
fig, ax = plt.subplots(figsize=(12,6))
ax.set_title('Fare vs Age')
ax.set_xlabel('Age')
ax.set_ylabel('Fare')
sns.scatterplot(x=titanic['Age'], y=titanic['Fare'], ax=ax)
plt.show()
fig.savefig('figures/Fare_vs_Age_seaborn.png')

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
fig, ax = plt.subplots(figsize=(12,6))
ax.set_title('Correlation matrix')
sns.heatmap(titanic.corr(), annot=True, ax=ax)
plt.show()
fig.savefig('figures/Correlation_matrix.png')
# Out:
# C:\Users\marti\AppData\Local\Temp\ipykernel_21500\186499660.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic.corr(), annot=True, ax=ax)

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
Fare and Pclass are the most correlated features. The correlation between Fare and Pclass is -0.55. The correlation between Fare and Survived is 0.26. The correlation between Pclass and Survived is -0.34.
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
fig, ax = plt.subplots(figsize=(12,6))
ax.set_title('Age summary statistics by Pclass')
ax.set_xlabel('Pclass')
ax.set_ylabel('Age')
sns.boxplot(x=titanic['Pclass'], y=titanic['Age'], ax=ax)
plt.show()
fig.savefig('figures/Age_summary_statistics_by_Pclass.png')

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
sns.FacetGrid(data=titanic, col='Gender', margin_titles=True, height=8).map_dataframe(sns.histplot, x="Age")
